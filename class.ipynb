# %%
class Thar:
    model=2015
    colour='red'

thar1=Thar
print(thar1.model)
print(thar1.colour)
# Out:
# 2015
# red

# %%
class State:
    state1="telangana"
    state2="delhi"
    state3="uttarpradesh"

state4=State
print(state4.state1)
print(state4.state3)
# Out:
# telangana
# uttarpradesh

# %%
class Student:
   def __init__(self,name,age):
    self.name=name
    self.age=age

s1=Student("ananya","19")
print(s1.name)
print(s1.age)
# Out:
# ananya
# 19

# %%
class Student:
   def __init__(self,name,age):
    self.name=name
    self.age=age

s1=Student("ananya","19")
print(s1.name)
print(s1.age)
# Out:
# ananya
# 19
