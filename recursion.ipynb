# %%
def count(n):
    if n==0:
        return
    print(n)
    count(n-1)
count(6)
# Out:
# 6
# 5
# 4
# 3
# 2
# 1

# %%
def count(n):
    if n==0:
        return
    print('hello')
    count(n-1)
count(6)
# Out:
# hello
# hello
# hello
# hello
# hello
# hello

# %%
def fact(n):
    if n==1:
        return 1
    return n*fact(n-1)
    
print(fact(9))
# Out:
# 362880
