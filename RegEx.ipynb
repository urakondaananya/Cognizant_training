# %%
import re
text="python is easy"
result=re.search("python", text)
print(result)
# Out:
# <re.Match object; span=(0, 6), match='python'>

# %%
import re
text="i have 10 books 28 pens"
result=re.findall(r"\d",text)
print(result)
# Out:
# ['1', '0', '2', '8']

# %%
import re
text="i have 10 books 28 pens"
result=re.findall(r"\d+",text)
print(result)
# Out:
# ['10', '28']

# %%
import re
text="python programming"
result=re.match("python", text)
print(result.group())
# Out:
# python

# %%
import re
text="phython,programming"
result=re.split(",", text)
print(result)
# Out:
# ['phython', 'programming']

# %%
import re
text="i love dog"
result=re.sub("dog","cat",text)
print(result)
# Out:
# i love cat

# %%
import re
text="my age is 19"
result=re.findall(r"\d+",text)
print(result)
# Out:
# ['19']

# %%
import re
text="my age is 19"
result=re.findall(r"\d",text)
print(result)
# Out:
# ['1', '9']

# %%
import re
email='lillytyrell@gmail.com'
pattern= r"^[a-zA-Z0-9.!#$%&'*+/=?^_`{|}~-]+@[a-zA-Z0-9-]+(?:\.[a-zA-Z0-9-]+)*$"
if re.match(pattern,email):
      print("valid")    
else:
    print("invalid")
# Out:
# valid

# %%
import re
email='lillytyrellgmail.com'
pattern= r'^[a-zA-Z0-9]+@[a-zA]+\.[a-zA]+$'
if re.match(pattern,email):
      print("valid")    
else:
    print("invalid")
# Out:
# invalid
