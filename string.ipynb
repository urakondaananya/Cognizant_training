# %%
name="ananya"
email="urakondaananya@gmail.com"
print(name)
print(email)
# Out:
# ananya
# urakondaananya@gmail.com

# %%
email="urakondaananya@gmail.com"
print(email)
# Out:
# urakondaananya@gmail.com

# %%
city="warangal"
print(city[-5])
# Out:
# a

# %%
bird="parrot"
print(bird[1:5])
# Out:
# arro

# %%
bird="sparrow"
print(len(bird))
# Out:
# 7

# %%
animal="monkey"
bird="sparrow"
print(animal+ "" +bird)
# Out:
# monkeysparrow

# %%
a="hello"
print("a" * 4,"hello" * 3)
# Out:
# aaaa hellohellohello

# %%
color="black"
print(color.upper())
# Out:
# BLACK

# %%
food="BIRYANI"
print(food.lower())
# Out:
# biryani

# %%
q="I love sweets"
print(q.replace("sweets","cakes"))
# Out:
# I love cakes

# %%
d="you're looking good"
print(d.find("good"))
# Out:
# 15

# %%
name=input("enter the name:")
print("welcome",name)
