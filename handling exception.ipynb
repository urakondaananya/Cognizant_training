# %%
num=10
print(num/0)
print("last line of the error")
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 num=10
# ----> 2 print(num/0)
#       3 print("last line of the error")
#
# ZeroDivisionError: division by zero

# %%
try:
    num=10
    print(num/0)
except ZeroDivisionError :
    print("10 is not didvided by 0")
# Out:
# 10 is not didvided by 0

# %%
file=open("index.txt","w")
file.write("hello ashmitha")
file.close()

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 file=open("demo2.txt","r")
#       2 content=file.read()
#       3 print(content)
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:343, in _modified_open(file, *args, **kwargs)
#     336 if file in {0, 1, 2}:
#     337     raise ValueError(
#     338         f"IPython won't let you open fd={file} by default "
#     339         "as it is likely to crash IPython. If you know what you are doing, "
#     340         "you can use builtins' open."
#     341     )
# --> 343 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'demo2.txt'

# %%
try:
    file=open("index.txt","r")

except FileNotFoundError:
    print("file does not exist")
# Out:
# file does not exist

# %%
try:
    age =int(input("enter your age:"))

except ValueError:
    print("only enter number")
# Out:
# enter your age: 73

# %%
try:
    phonenumber=int(input("enter your phone number:")) 

except ValueError:
 print("only enter digits")
# Out:
# enter your phone number: hefds
# only enter digits
