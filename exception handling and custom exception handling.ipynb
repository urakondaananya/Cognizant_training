# %%
num=10
print(num/0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 num=10
# ----> 2 print(num/0)
#
# ZeroDivisionError: division by zero

# %%
try:
    num=int(input('enter the number:'))
    print(num/8)
    
except ValueError:
    print("not valid")
except ZeroDivisionError:
    print("cannot divide by zero")
# Out:
# enter the number: 90
# 11.25

# %%
try:
    value=int(input('enter the number:'))
    print(value/8)
    
except ValueError:
    print("not valid")
except ZeroDivisionError:
    print("cannot divide by zero")
else:
    print("code executed successfully")
# Out:
# enter the number: 100
# 12.5
# code executed successfully

# %%
try:
    value=int(input('enter the number:'))
    print(value/8)
    
except ValueError:
    print("not valid")
except ZeroDivisionError:
    print("cannot divide by zero")
else:
    print("code executed successfully")
finally:
    print("this block executes everytime")
# Out:
# enter the number: 96
# 12.0
# code executed successfully
# this block executes everytime

# %%
age=int(input("enter the age:"))
if age<18:
 raise Exception ("you're not eligible to vote")
else:
 print('eligible')
# Out:
# enter the age: 19
# eligible

# %%
age=int(input("enter the age:"))
if age<18:
 raise Exception ("you're not eligible to vote")
else:
 print('eligible')
# Out:
# enter the age: 7
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 age=int(input("enter the age:"))
#       2 if age<18:
# ----> 3  raise Exception ("you're not eligible to vote")
#       4 else:
#       5  print('eligible')
#
# Exception: you're not eligible to vote

# %%
friut=input("enter flower:")
if 'flower'=='tulip':
    raise Exception ("flower is not found")
else:
    print('flower is found')
# Out:
# enter flower: rose
# flower is found

# %%
try:
   value=int(input('enter the number:'))
   value1=int(input('enter the number:'))
   print(value+value1)
   print(value+value1/9)

except ValueError:
      print("enter only numbers")
except ZeroDivisionError:
      print("cannot divide number by zero")
else:
    print("code is executed successfully")
finally:
    print("finaaly block executes evrytime")
# Out:
# enter the number: 90
# enter the number: 56
# 146
# 96.22222222222223
# code is executed successfully
# finaaly block executes evrytime
