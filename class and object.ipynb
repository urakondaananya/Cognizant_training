# %%
class Thar:
    model=2015
    colour='red'

thar1=Thar
print(thar1.model)
print(thar1.colour)
# Out:
# 2015
# red

# %%
class State:
    state1="telangana"
    state2="delhi"
    state3="uttarpradesh"

state4=State
print(state4.state1)
print(state4.state3)
# Out:
# telangana
# uttarpradesh

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 class Student:
#       2   def__init__(self,name,age)
#       3   self.name=name
#
# Cell In[19], line 2, in Student()
#       1 class Student:
# ----> 2   def__init__(self,name,age)
#       3   self.name=name
#       4   self.age=age
#
# NameError: name 'def__init__' is not defined

# %%
s1=Student("kavitha",32)
print(s1.name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 s1=Student("kavitha",32)
#       2 print(s1.name)
#
# NameError: name 'Student' is not defined

# %%
class Student:
   def __init__(self,name,age):
    self.name=name
    self.age=age

s1=Student("ananya","19")
print(s1.name)
print(s1.age)
# Out:
# ananya
# 19

# %%
s1=Student("ananya",19)
print(s1.name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 s1=Student("ananya",19)
#       2 print(s1.name)
#
# NameError: name 'Student' is not defined

# %%
class Student:
   def __init__(self,name,age):
    self.name=name
    self.age=age

s1=Student("ananya","19")
print(s1.name)
print(s1.age)
# Out:
# ananya
# 19
