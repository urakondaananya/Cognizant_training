# %%
lst=["a","b","c","d","e"]
it=iter(lst)
print(next(it))
print(next(it))
print(next(it))
# Out:
# a
# b
# c

# %%
num=[1,2,3,4,5]
it=iter(num)
print(next(it))
print(next(it))
print(next(it))
print(next(it))
print(next(it))
# Out:
# 1
# 2
# 3
# 4
# 5
