# %%
def students(*marks):
    print(sum(marks))
students(50,50)   
students(20,35)
# Out:
# 100
# 55

# %%
def student(*marks):
    print(sum(marks))
student(50,50)   
student(20,35)
# Out:
# 100
# 55

# %%
def student(*marks):
    print(sum(marks))
student(50,980)   
student(20,35)
# Out:
# 1030
# 55

# %% [raw]
# p

# %%
print(10+20)
print("ananya"+ " " +"urakonda")
# Out:
# 30
# ananya urakonda

# %%
class Student:
    def __init__(self,marks):
        self.marks=marks

    def __add__(self,other):
        return self.marks+other.marks
        
s1=Student(75)
s2=Student(79)
print(s1+s2)
# Out:
# 154

# %%
class Student:
    def __init__(self,marks):
        self.marks=marks

    def __add__(self,other):
        return self.marks+other.marks
        
s1=Student(75)
s2=Student(79)
print(s1+s2)
# Out:
# 154
